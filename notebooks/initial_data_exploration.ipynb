# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Loading the data

# %%
df = pd.read_csv('../MPRebellionPredictor/data/labour_rebellions.csv')
df.head()
# Out:
#          Candidate  Rebellions  EuropeRebellions  NonEuroperebellions  \
# 0        Kate Hoey         103                82                   21
# 1  Graham Stringer          69                60                    9
# 2        John Mann          46                40                    6
# 3  Ronnie Campbell          40                36                    4
# 4     Kevin Barron          35                32                    3
#
#    PreCorbynfrontbench  ExCorbynfrontbench  Corbynfrontbench  Resignedwhip  \
# 0                    1                   0                 0             0
# 1                    1                   0                 0             0
# 2                    0                   0                 0             1
# 3                    0                   0                 0             0
# 4                    1                   0                 0             0
#
#    Electedin2017  Electedin2015  ...  noneuropebinary  Europebinary  \
# ...

# %%
# checking for null values

df.isnull().sum()
# Out:
# Candidate               0
# Rebellions              0
# EuropeRebellions        0
# NonEuroperebellions     0
# PreCorbynfrontbench     0
# ExCorbynfrontbench      0
# Corbynfrontbench        0
# Resignedwhip            0
# Electedin2017           0
# Electedin2015           0
# TribuneMember           0
# CampaignMember          0
# NominatedOwenSmith      0
# Majority                0
# leavevoteX100           0
# CLPsupportedSmith       0
# CLPsupportedCorbyn      0
# lneurope                0
# lnnoneurope             0
# lntotal                 0
# rebellionmedian         0
# noneuropebinary         0
# Europebinary            0
# rebellionsnooutliers    0
# europenooutliers        0
# IsFemale                0
# Backbench               0
# Constituency            0
# whenelected             0
# benchposition           0
# subgroupmembership      0
# dtype: int64
